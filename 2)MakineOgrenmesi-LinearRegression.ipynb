# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
veriler = pd.read_csv("satislar.csv")

# %%
veriler
# Out:
#     Aylar  Satislar
# 0       8   19671.5
# 1      10   23102.5
# 2      11   18865.5
# 3      13   21762.5
# 4      14   19945.5
# 5      19   28321.0
# 6      19   30075.0
# 7      20   27222.5
# 8      20   32222.5
# 9      24   28594.5
# 10     25   31609.0
# 11     25   27897.0
# 12     25   28478.5
# 13     26   28540.5
# 14     29   30555.5
# 15     31   33969.0
# 16     32   33014.5
# 17     34   41544.0
# 18     37   40681.5
# 19     37   46971.0
# 20     42   45869.0
# 21     44   49136.5
# 22     49   50651.0
# 23     50   56906.0
# 24     54   54715.5
# 25     55   52791.0
# 26     59   58484.5
# 27     59   56317.5
# 28     64   61195.5
# 29     65   60936.0

# %%
aylar = veriler[["Aylar"]]

# %%
aylar
# Out:
#     Aylar
# 0       8
# 1      10
# 2      11
# 3      13
# 4      14
# 5      19
# 6      19
# 7      20
# 8      20
# 9      24
# 10     25
# 11     25
# 12     25
# 13     26
# 14     29
# 15     31
# 16     32
# 17     34
# 18     37
# 19     37
# 20     42
# 21     44
# 22     49
# 23     50
# 24     54
# 25     55
# 26     59
# 27     59
# 28     64
# 29     65

# %%
satislar = veriler[["Satislar"]]

# %%
satislar
# Out:
#     Satislar
# 0    19671.5
# 1    23102.5
# 2    18865.5
# 3    21762.5
# 4    19945.5
# 5    28321.0
# 6    30075.0
# 7    27222.5
# 8    32222.5
# 9    28594.5
# 10   31609.0
# 11   27897.0
# 12   28478.5
# 13   28540.5
# 14   30555.5
# 15   33969.0
# 16   33014.5
# 17   41544.0
# 18   40681.5
# 19   46971.0
# 20   45869.0
# 21   49136.5
# 22   50651.0
# 23   56906.0
# 24   54715.5
# 25   52791.0
# 26   58484.5
# 27   56317.5
# 28   61195.5
# 29   60936.0

# %%
x_train , x_test , y_train , y_test = train_test_split(aylar,satislar,test_size=0.33,random_state=0)

# %%
x_train
# Out:
#     Aylar
# 5      19
# 16     32
# 8      20
# 14     29
# 23     50
# 20     42
# 1      10
# 29     65
# 6      19
# 4      14
# 18     37
# 19     37
# 9      24
# 7      20
# 25     55
# 3      13
# 0       8
# 21     44
# 15     31
# 12     25

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(x_train)

# %%
X_test = sc.fit_transform(x_test)

# %%
Y_train = sc.fit_transform(y_train)
Y_test = sc.fit_transform(y_test)

# %%
X_train
# Out:
# array([[-0.70368853],
#        [ 0.15126015],
#        [-0.63792324],
#        [-0.0460357 ],
#        [ 1.33503524],
#        [ 0.80891298],
#        [-1.29557607],
#        [ 2.32151449],
#        [-0.70368853],
#        [-1.03251494],
#        [ 0.48008657],
#        [ 0.48008657],
#        [-0.37486211],
#        [-0.63792324],
#        [ 1.66386166],
#        [-1.09828023],
#        [-1.42710664],
#        [ 0.94044355],
#        [ 0.08549487],
#        [-0.30909683]])

# %%
X_test
# Out:
# array([[-1.68268756],
#        [ 1.33023274],
#        [-0.82997427],
#        [-0.88682182],
#        [ 1.04599497],
#        [ 0.76175721],
#        [ 1.04599497],
#        [-0.88682182],
#        [-0.37519385],
#        [ 0.47751944]])

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train) # Modelin İnşaası X_train den Y_train tahmin etme işlemi...
# Out:
# LinearRegression()

# %%
tahmin = lr.predict(X_test)

# %%
tahmin
# Out:
# array([[-1.62717296],
#        [ 1.28634619],
#        [-0.80259207],
#        [-0.85756413],
#        [ 1.01148589],
#        [ 0.7366256 ],
#        [ 1.01148589],
#        [-0.85756413],
#        [-0.36281559],
#        [ 0.4617653 ]])

# %%
Y_test
# Out:
# array([[-1.66597621],
#        [ 1.25819492],
#        [-0.99762385],
#        [-0.7856508 ],
#        [ 1.0709181 ],
#        [ 0.81055426],
#        [ 0.92122098],
#        [-1.04207705],
#        [-0.09933754],
#        [ 0.52977719]])

# %%
lr.fit(x_train,y_train) 
tahmin2 = lr.predict(x_test)

# %%
tahmin2
# Out:
# array([[20991.95711691],
#        [62143.03587648],
#        [32638.48884131],
#        [31862.05339302],
#        [58260.85863501],
#        [54378.68139354],
#        [58260.85863501],
#        [31862.05339302],
#        [38849.97242766],
#        [50496.50415207]])

# %%
y_test
# Out:
#     Satislar
# 2    18865.5
# 28   61195.5
# 13   28540.5
# 10   31609.0
# 26   58484.5
# 24   54715.5
# 27   56317.5
# 11   27897.0
# 17   41544.0
# 22   50651.0

# %%
x_train = x_train.sort_index()

# %%
y_train = y_train.sort_index()

# %%
plt.plot(x_train,y_train)

# %%
x_test = x_test.sort_index()

# %%
plt.plot(x_test,lr.predict(x_test))
plt.plot(x_train,y_train)

# %%
lr.predict(x_test)
# Out:
# array([[20991.95711691],
#        [31862.05339302],
#        [31862.05339302],
#        [32638.48884131],
#        [38849.97242766],
#        [50496.50415207],
#        [54378.68139354],
#        [58260.85863501],
#        [58260.85863501],
#        [62143.03587648]])

# %%
y_test
# Out:
#     Satislar
# 2    18865.5
# 28   61195.5
# 13   28540.5
# 10   31609.0
# 26   58484.5
# 24   54715.5
# 27   56317.5
# 11   27897.0
# 17   41544.0
# 22   50651.0
